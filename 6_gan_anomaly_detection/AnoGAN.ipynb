# %%
# 패키지 import
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# ## DCGAN 학습

# %%
class Generator(nn.Module):
    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size*8, kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size*8),
            nn.ReLU(inplace=True)
        )

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size*8, image_size*4, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size*4),
            nn.ReLU(inplace=True)
        )

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size*4, image_size*2, kernel_size=4, stride=2,padding=1),
            nn.BatchNorm2d(image_size*2),
            nn.ReLU(inplace=True)
        )

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size*2, image_size, kernel_size=4, stride=2,padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True)
        )

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size,1,kernel_size=4, stride=2,padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
class Discriminator(nn.Module):
    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)

        feature = out
        feature = feature.view(feature.size()[0], -1)

        out = self.last(out)

        return out, feature

# %% [markdown]
# ## AnoGAN의 손실함수

# %%
def Anomaly_score(x, fake_img, D, Lambda=0.1):
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    _, x_feature = D(x)
    _, G_feature = D(fake_img)

    discrimination_loss = torch.abs(x_feature - G_feature)
    discrimination_loss = discrimination_loss.view(discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %% [markdown]
# ## AnoGAN 학습 구현과 이상 탐지 실시

# %%
def make_datapath_list():
    """학습 및 검증 화상 데이터와 어노테이션 데이터의 파일 경로 리스트를 작성한다. """

    train_img_list = list()  # 화상 파일 경로를 저장

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list



class ImageTransform():
    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

class GAN_Img_Dataset(data.Dataset):
    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, index):
        img_path = self.file_list[index]
        img = Image.open(img_path)

        img_transformed = self.transform(img)

        return img_transformed
        
train_img_list=make_datapath_list()

# Dataset 작성
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoader 작성
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 동작 확인
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2d 초기화
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2d 초기화
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

D = Discriminator(z_dim=20, image_size=64)
G = Generator(z_dim=20, image_size=64)

# 초기화 실시
G.apply(weights_init)
D.apply(weights_init)

print("네트워크 초기화 완료")
# Out:
# 네트워크 초기화 완료

# %%
# 모델을 학습시키는 함수를 작성
def train_model(G, D, dataloader, num_epochs):

    # GPU가 사용 가능한지 확인
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("사용 장치: ", device)

    # 최적화 기법 설정
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 오차함수 정의
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # 파라미터를 하드코딩
    z_dim = 20
    mini_batch_size = 64

    # 네트워크를 GPU로
    G.to(device)
    D.to(device)

    G.train()  # 모델을 훈련 모드로
    D.train()  # 모델을 훈련 모드로

    # 네트워크가 어느 정도 고정되면, 고속화시킨다
    torch.backends.cudnn.benchmark = True

    # 화상의 매수
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # 반복 카운터 설정
    iteration = 1
    logs = []

    # epoch 루프
    for epoch in range(num_epochs):

        # 개시 시간을 저장
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epoch의 손실합
        epoch_d_loss = 0.0  # epoch의 손실합

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('(train)')

        # 데이터 로더에서 minibatch씩 꺼내는 루프
        for imges in dataloader:

            # --------------------
            # 1. Discriminator 학습
            # --------------------
            # 미니 배치 크기가 1이면, 배치 노멀라이제이션에서 에러가 발생하므로 피한다
            if imges.size()[0] == 1:
                continue

            # GPU가 사용 가능하면 GPU로 데이터를 보낸다
            imges = imges.to(device)

            # 정답 라벨과 가짜 라벨 작성
            # epoch의 마지막 반복은 미니 배치 수가 줄어든다
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)
            label_real = label_real.float()
            label_fake = label_fake.float()
            # 진짜 화상을 판정
            d_out_real, _ = D(imges)

            # 가짜 화상을 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 오차를 계산
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generator 학습
            # --------------------
            # 가짜 화상을 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 오차를 계산
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 기록
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epoch의 phase별 loss와 정답률
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    
    print("총 반복 횟수: ", iteration)

    return G, D

# %%
# 학습 및 검증을 실행한다
# 8분 정도 걸립니다
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 사용 장치:  cuda:0
# -------------
# Epoch 0/300
# -------------
# (train)
# -------------
# epoch 0 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.2345
# timer:  0.3945 sec.
# -------------
# Epoch 1/300
# -------------
# (train)
# -------------
# epoch 1 || Epoch_D_Loss:0.0315 ||Epoch_G_Loss:0.3797
# timer:  0.2924 sec.
# -------------
# Epoch 2/300
# -------------
# (train)
# -------------
# epoch 2 || Epoch_D_Loss:0.1126 ||Epoch_G_Loss:0.4288
# timer:  0.2898 sec.
# -------------
# Epoch 3/300
# -------------
# (train)
# -------------
# epoch 3 || Epoch_D_Loss:0.0817 ||Epoch_G_Loss:0.1035
# timer:  0.3006 sec.
# -------------
# Epoch 4/300
# -------------
# (train)
# -------------
# epoch 4 || Epoch_D_Loss:0.0564 ||Epoch_G_Loss:0.2211
# timer:  0.2906 sec.
# -------------
# Epoch 5/300
# -------------
# (train)
# -------------
# epoch 5 || Epoch_D_Loss:0.0087 ||Epoch_G_Loss:0.4239
# timer:  0.2964 sec.
# -------------
# Epoch 6/300
# -------------
# (train)
# -------------
# epoch 6 || Epoch_D_Loss:0.0071 ||Epoch_G_Loss:0.4189
# timer:  0.2877 sec.
# -------------
# Epoch 7/300
# -------------
# (train)
# -------------
# epoch 7 || Epoch_D_Loss:0.1980 ||Epoch_G_Loss:0.1787
# timer:  0.2950 sec.
# -------------
# Epoch 8/300
# -------------
# (train)
# -------------
# epoch 8 || Epoch_D_Loss:0.0092 ||Epoch_G_Loss:0.3918
# timer:  0.2955 sec.
# -------------
# Epoch 9/300
# -------------
# (train)
# -------------
# epoch 9 || Epoch_D_Loss:0.3050 ||Epoch_G_Loss:0.2249
# timer:  0.2889 sec.
# -------------
# Epoch 10/300
# -------------
# (train)
# -------------
# epoch 10 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.1293
# timer:  0.2948 sec.
# -------------
# Epoch 11/300
# -------------
# (train)
# -------------
# epoch 11 || Epoch_D_Loss:0.0381 ||Epoch_G_Loss:0.2079
# timer:  0.2934 sec.
# -------------
# Epoch 12/300
# -------------
# (train)
# -------------
# epoch 12 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.4219
# timer:  0.2879 sec.
# -------------
# Epoch 13/300
# -------------
# (train)
# -------------
# epoch 13 || Epoch_D_Loss:0.0302 ||Epoch_G_Loss:0.5406
# timer:  0.2913 sec.
# -------------
# Epoch 14/300
# -------------
# (train)
# -------------
# epoch 14 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.5579
# timer:  0.2886 sec.
# -------------
# Epoch 15/300
# -------------
# (train)
# -------------
# epoch 15 || Epoch_D_Loss:0.0032 ||Epoch_G_Loss:0.6259
# timer:  0.2928 sec.
# -------------
# Epoch 16/300
# -------------
# (train)
# -------------
# epoch 16 || Epoch_D_Loss:0.1636 ||Epoch_G_Loss:0.5602
# timer:  0.2926 sec.
# -------------
# Epoch 17/300
# -------------
# (train)
# -------------
# epoch 17 || Epoch_D_Loss:0.0144 ||Epoch_G_Loss:0.5005
# timer:  0.2899 sec.
# -------------
# Epoch 18/300
# -------------
# (train)
# -------------
# epoch 18 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.5464
# timer:  0.2933 sec.
# -------------
# Epoch 19/300
# -------------
# (train)
# -------------
# epoch 19 || Epoch_D_Loss:0.2951 ||Epoch_G_Loss:0.4912
# timer:  0.2944 sec.
# -------------
# Epoch 20/300
# -------------
# (train)
# -------------
# epoch 20 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4651
# timer:  0.2918 sec.
# -------------
# Epoch 21/300
# -------------
# (train)
# -------------
# epoch 21 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.5597
# timer:  0.2886 sec.
# -------------
# Epoch 22/300
# -------------
# (train)
# -------------
# epoch 22 || Epoch_D_Loss:0.3101 ||Epoch_G_Loss:0.1645
# timer:  0.2911 sec.
# -------------
# Epoch 23/300
# -------------
# (train)
# -------------
# epoch 23 || Epoch_D_Loss:0.0965 ||Epoch_G_Loss:0.2565
# timer:  0.2959 sec.
# -------------
# Epoch 24/300
# -------------
# (train)
# -------------
# epoch 24 || Epoch_D_Loss:0.0273 ||Epoch_G_Loss:0.3857
# timer:  0.2946 sec.
# -------------
# Epoch 25/300
# -------------
# (train)
# -------------
# epoch 25 || Epoch_D_Loss:0.1942 ||Epoch_G_Loss:0.1208
# timer:  0.2954 sec.
# -------------
# Epoch 26/300
# -------------
# (train)
# -------------
# epoch 26 || Epoch_D_Loss:0.0305 ||Epoch_G_Loss:0.2973
# timer:  0.2928 sec.
# -------------
# Epoch 27/300
# -------------
# (train)
# -------------
# epoch 27 || Epoch_D_Loss:0.1428 ||Epoch_G_Loss:0.3482
# timer:  0.2876 sec.
# -------------
# Epoch 28/300
# -------------
# (train)
# -------------
# epoch 28 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.2822
# timer:  0.2944 sec.
# -------------
# Epoch 29/300
# -------------
# (train)
# -------------
# epoch 29 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.2339
# timer:  0.2882 sec.
# -------------
# Epoch 30/300
# -------------
# (train)
# -------------
# epoch 30 || Epoch_D_Loss:0.1422 ||Epoch_G_Loss:0.2272
# timer:  0.2956 sec.
# -------------
# Epoch 31/300
# -------------
# (train)
# -------------
# epoch 31 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.1977
# timer:  0.2959 sec.
# -------------
# Epoch 32/300
# -------------
# (train)
# -------------
# epoch 32 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.2448
# timer:  0.2931 sec.
# -------------
# Epoch 33/300
# -------------
# (train)
# -------------
# epoch 33 || Epoch_D_Loss:0.1306 ||Epoch_G_Loss:0.2176
# timer:  0.2901 sec.
# -------------
# Epoch 34/300
# -------------
# (train)
# -------------
# epoch 34 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1623
# timer:  0.2946 sec.
# -------------
# Epoch 35/300
# -------------
# (train)
# -------------
# epoch 35 || Epoch_D_Loss:0.1172 ||Epoch_G_Loss:0.1827
# timer:  0.2873 sec.
# -------------
# Epoch 36/300
# -------------
# (train)
# -------------
# epoch 36 || Epoch_D_Loss:0.1112 ||Epoch_G_Loss:0.1801
# timer:  0.2890 sec.
# -------------
# Epoch 37/300
# -------------
# (train)
# -------------
# epoch 37 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.1883
# timer:  0.2961 sec.
# -------------
# Epoch 38/300
# -------------
# (train)
# -------------
# epoch 38 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.1811
# timer:  0.2896 sec.
# -------------
# Epoch 39/300
# -------------
# (train)
# -------------
# epoch 39 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.1938
# timer:  0.2892 sec.
# -------------
# Epoch 40/300
# -------------
# (train)
# -------------
# epoch 40 || Epoch_D_Loss:0.1207 ||Epoch_G_Loss:0.1775
# timer:  0.3020 sec.
# -------------
# Epoch 41/300
# -------------
# (train)
# -------------
# epoch 41 || Epoch_D_Loss:0.1026 ||Epoch_G_Loss:0.1849
# timer:  0.2943 sec.
# -------------
# Epoch 42/300
# -------------
# (train)
# -------------
# epoch 42 || Epoch_D_Loss:0.1094 ||Epoch_G_Loss:0.1840
# timer:  0.2856 sec.
# -------------
# Epoch 43/300
# -------------
# (train)
# -------------
# epoch 43 || Epoch_D_Loss:0.1020 ||Epoch_G_Loss:0.1299
# timer:  0.2994 sec.
# -------------
# Epoch 44/300
# -------------
# (train)
# -------------
# epoch 44 || Epoch_D_Loss:0.1190 ||Epoch_G_Loss:0.1702
# timer:  0.2890 sec.
# -------------
# Epoch 45/300
# -------------
# (train)
# -------------
# epoch 45 || Epoch_D_Loss:0.1191 ||Epoch_G_Loss:0.1449
# timer:  0.2957 sec.
# -------------
# Epoch 46/300
# -------------
# (train)
# -------------
# epoch 46 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1561
# timer:  0.2952 sec.
# -------------
# Epoch 47/300
# -------------
# (train)
# -------------
# epoch 47 || Epoch_D_Loss:0.1193 ||Epoch_G_Loss:0.1611
# timer:  0.2902 sec.
# -------------
# Epoch 48/300
# -------------
# (train)
# -------------
# epoch 48 || Epoch_D_Loss:0.1089 ||Epoch_G_Loss:0.1442
# timer:  0.2934 sec.
# -------------
# Epoch 49/300
# -------------
# (train)
# -------------
# epoch 49 || Epoch_D_Loss:0.1157 ||Epoch_G_Loss:0.1522
# timer:  0.2942 sec.
# -------------
# Epoch 50/300
# -------------
# (train)
# -------------
# epoch 50 || Epoch_D_Loss:0.1364 ||Epoch_G_Loss:0.1539
# timer:  0.2880 sec.
# -------------
# Epoch 51/300
# -------------
# (train)
# -------------
# epoch 51 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1342
# timer:  0.2975 sec.
# -------------
# Epoch 52/300
# -------------
# (train)
# -------------
# epoch 52 || Epoch_D_Loss:0.1148 ||Epoch_G_Loss:0.1559
# timer:  0.2863 sec.
# -------------
# Epoch 53/300
# -------------
# (train)
# -------------
# epoch 53 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1413
# timer:  0.2959 sec.
# -------------
# Epoch 54/300
# -------------
# (train)
# -------------
# epoch 54 || Epoch_D_Loss:0.1491 ||Epoch_G_Loss:0.1856
# timer:  0.2935 sec.
# -------------
# Epoch 55/300
# -------------
# (train)
# -------------
# epoch 55 || Epoch_D_Loss:0.1169 ||Epoch_G_Loss:0.1090
# timer:  0.2872 sec.
# -------------
# Epoch 56/300
# -------------
# (train)
# -------------
# epoch 56 || Epoch_D_Loss:0.1095 ||Epoch_G_Loss:0.1430
# timer:  0.2916 sec.
# -------------
# Epoch 57/300
# -------------
# (train)
# -------------
# epoch 57 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1421
# timer:  0.2872 sec.
# -------------
# Epoch 58/300
# -------------
# (train)
# -------------
# epoch 58 || Epoch_D_Loss:0.1098 ||Epoch_G_Loss:0.1521
# timer:  0.2863 sec.
# -------------
# Epoch 59/300
# -------------
# (train)
# -------------
# epoch 59 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.1402
# timer:  0.2871 sec.
# -------------
# Epoch 60/300
# -------------
# (train)
# -------------
# epoch 60 || Epoch_D_Loss:0.1146 ||Epoch_G_Loss:0.1430
# timer:  0.2892 sec.
# -------------
# Epoch 61/300
# -------------
# (train)
# -------------
# epoch 61 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1429
# timer:  0.2865 sec.
# -------------
# Epoch 62/300
# -------------
# (train)
# -------------
# epoch 62 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1563
# timer:  0.2939 sec.
# -------------
# Epoch 63/300
# -------------
# (train)
# -------------
# epoch 63 || Epoch_D_Loss:0.1215 ||Epoch_G_Loss:0.1600
# timer:  0.2904 sec.
# -------------
# Epoch 64/300
# -------------
# (train)
# -------------
# epoch 64 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1690
# timer:  0.2883 sec.
# -------------
# Epoch 65/300
# -------------
# (train)
# -------------
# epoch 65 || Epoch_D_Loss:0.0934 ||Epoch_G_Loss:0.1482
# timer:  0.2941 sec.
# -------------
# Epoch 66/300
# -------------
# (train)
# -------------
# epoch 66 || Epoch_D_Loss:0.0970 ||Epoch_G_Loss:0.1793
# timer:  0.2994 sec.
# -------------
# Epoch 67/300
# -------------
# (train)
# -------------
# epoch 67 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1715
# timer:  0.2920 sec.
# -------------
# Epoch 68/300
# -------------
# (train)
# -------------
# epoch 68 || Epoch_D_Loss:0.0796 ||Epoch_G_Loss:0.1810
# timer:  0.2885 sec.
# -------------
# Epoch 69/300
# -------------
# (train)
# -------------
# epoch 69 || Epoch_D_Loss:0.1081 ||Epoch_G_Loss:0.1825
# timer:  0.2883 sec.
# -------------
# Epoch 70/300
# -------------
# (train)
# -------------
# epoch 70 || Epoch_D_Loss:0.0840 ||Epoch_G_Loss:0.1820
# timer:  0.2863 sec.
# -------------
# Epoch 71/300
# -------------
# (train)
# -------------
# epoch 71 || Epoch_D_Loss:0.0887 ||Epoch_G_Loss:0.1985
# timer:  0.2881 sec.
# -------------
# Epoch 72/300
# -------------
# (train)
# -------------
# epoch 72 || Epoch_D_Loss:0.1085 ||Epoch_G_Loss:0.1863
# timer:  0.2895 sec.
# -------------
# Epoch 73/300
# -------------
# (train)
# -------------
# epoch 73 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.1725
# timer:  0.2893 sec.
# -------------
# Epoch 74/300
# -------------
# (train)
# -------------
# epoch 74 || Epoch_D_Loss:0.0848 ||Epoch_G_Loss:0.1973
# timer:  0.2888 sec.
# -------------
# Epoch 75/300
# -------------
# (train)
# -------------
# epoch 75 || Epoch_D_Loss:0.0855 ||Epoch_G_Loss:0.2068
# timer:  0.2876 sec.
# -------------
# Epoch 76/300
# -------------
# (train)
# -------------
# epoch 76 || Epoch_D_Loss:0.0926 ||Epoch_G_Loss:0.1896
# timer:  0.2914 sec.
# -------------
# Epoch 77/300
# -------------
# (train)
# -------------
# epoch 77 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.2026
# timer:  0.2920 sec.
# -------------
# Epoch 78/300
# -------------
# (train)
# -------------
# epoch 78 || Epoch_D_Loss:0.0853 ||Epoch_G_Loss:0.1801
# timer:  0.2925 sec.
# -------------
# Epoch 79/300
# -------------
# (train)
# -------------
# epoch 79 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.1845
# timer:  0.2938 sec.
# -------------
# Epoch 80/300
# -------------
# (train)
# -------------
# epoch 80 || Epoch_D_Loss:0.0866 ||Epoch_G_Loss:0.1974
# timer:  0.2932 sec.
# -------------
# Epoch 81/300
# -------------
# (train)
# -------------
# epoch 81 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.2122
# timer:  0.2928 sec.
# -------------
# Epoch 82/300
# -------------
# (train)
# -------------
# epoch 82 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1753
# timer:  0.2853 sec.
# -------------
# Epoch 83/300
# -------------
# (train)
# -------------
# epoch 83 || Epoch_D_Loss:0.0976 ||Epoch_G_Loss:0.1926
# timer:  0.3007 sec.
# -------------
# Epoch 84/300
# -------------
# (train)
# -------------
# epoch 84 || Epoch_D_Loss:0.0823 ||Epoch_G_Loss:0.1791
# timer:  0.2938 sec.
# -------------
# Epoch 85/300
# -------------
# (train)
# -------------
# epoch 85 || Epoch_D_Loss:0.0838 ||Epoch_G_Loss:0.2028
# timer:  0.2920 sec.
# -------------
# Epoch 86/300
# -------------
# (train)
# -------------
# epoch 86 || Epoch_D_Loss:0.1036 ||Epoch_G_Loss:0.1938
# timer:  0.2927 sec.
# -------------
# Epoch 87/300
# -------------
# (train)
# -------------
# epoch 87 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.1794
# timer:  0.2930 sec.
# -------------
# Epoch 88/300
# -------------
# (train)
# -------------
# epoch 88 || Epoch_D_Loss:0.1007 ||Epoch_G_Loss:0.1852
# timer:  0.2948 sec.
# -------------
# Epoch 89/300
# -------------
# (train)
# -------------
# epoch 89 || Epoch_D_Loss:0.0654 ||Epoch_G_Loss:0.2184
# timer:  0.2857 sec.
# -------------
# Epoch 90/300
# -------------
# (train)
# -------------
# epoch 90 || Epoch_D_Loss:0.0996 ||Epoch_G_Loss:0.1816
# timer:  0.2930 sec.
# -------------
# Epoch 91/300
# -------------
# (train)
# -------------
# epoch 91 || Epoch_D_Loss:0.0776 ||Epoch_G_Loss:0.1947
# timer:  0.2941 sec.
# -------------
# Epoch 92/300
# -------------
# (train)
# -------------
# epoch 92 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.2034
# timer:  0.2901 sec.
# -------------
# Epoch 93/300
# -------------
# (train)
# -------------
# epoch 93 || Epoch_D_Loss:0.0814 ||Epoch_G_Loss:0.2106
# timer:  0.2923 sec.
# -------------
# Epoch 94/300
# -------------
# (train)
# -------------
# epoch 94 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.1813
# timer:  0.3016 sec.
# -------------
# Epoch 95/300
# -------------
# (train)
# -------------
# epoch 95 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.2059
# timer:  0.2856 sec.
# -------------
# Epoch 96/300
# -------------
# (train)
# -------------
# epoch 96 || Epoch_D_Loss:0.0983 ||Epoch_G_Loss:0.1984
# timer:  0.2907 sec.
# -------------
# Epoch 97/300
# -------------
# (train)
# -------------
# epoch 97 || Epoch_D_Loss:0.0818 ||Epoch_G_Loss:0.2193
# timer:  0.2965 sec.
# -------------
# Epoch 98/300
# -------------
# (train)
# -------------
# epoch 98 || Epoch_D_Loss:0.0769 ||Epoch_G_Loss:0.2008
# timer:  0.3035 sec.
# -------------
# Epoch 99/300
# -------------
# (train)
# -------------
# epoch 99 || Epoch_D_Loss:0.0683 ||Epoch_G_Loss:0.2343
# timer:  0.2940 sec.
# -------------
# Epoch 100/300
# -------------
# (train)
# -------------
# epoch 100 || Epoch_D_Loss:0.0702 ||Epoch_G_Loss:0.2770
# timer:  0.2906 sec.
# -------------
# Epoch 101/300
# -------------
# (train)
# -------------
# epoch 101 || Epoch_D_Loss:0.1044 ||Epoch_G_Loss:0.1627
# timer:  0.2958 sec.
# -------------
# Epoch 102/300
# -------------
# (train)
# -------------
# epoch 102 || Epoch_D_Loss:0.0736 ||Epoch_G_Loss:0.2216
# timer:  0.3035 sec.
# -------------
# Epoch 103/300
# -------------
# (train)
# -------------
# epoch 103 || Epoch_D_Loss:0.0757 ||Epoch_G_Loss:0.2173
# timer:  0.2936 sec.
# -------------
# Epoch 104/300
# -------------
# (train)
# -------------
# epoch 104 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.2431
# timer:  0.2891 sec.
# -------------
# Epoch 105/300
# -------------
# (train)
# -------------
# epoch 105 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1770
# timer:  0.2924 sec.
# -------------
# Epoch 106/300
# -------------
# (train)
# -------------
# epoch 106 || Epoch_D_Loss:0.0611 ||Epoch_G_Loss:0.2525
# timer:  0.2923 sec.
# -------------
# Epoch 107/300
# -------------
# (train)
# -------------
# epoch 107 || Epoch_D_Loss:0.0893 ||Epoch_G_Loss:0.1917
# timer:  0.2876 sec.
# -------------
# Epoch 108/300
# -------------
# (train)
# -------------
# epoch 108 || Epoch_D_Loss:0.0732 ||Epoch_G_Loss:0.2491
# timer:  0.2901 sec.
# -------------
# Epoch 109/300
# -------------
# (train)
# -------------
# epoch 109 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1858
# timer:  0.2881 sec.
# -------------
# Epoch 110/300
# -------------
# (train)
# -------------
# epoch 110 || Epoch_D_Loss:0.0756 ||Epoch_G_Loss:0.2180
# timer:  0.2931 sec.
# -------------
# Epoch 111/300
# -------------
# (train)
# -------------
# epoch 111 || Epoch_D_Loss:0.0804 ||Epoch_G_Loss:0.2393
# timer:  0.2921 sec.
# -------------
# Epoch 112/300
# -------------
# (train)
# -------------
# epoch 112 || Epoch_D_Loss:0.0685 ||Epoch_G_Loss:0.2279
# timer:  0.2937 sec.
# -------------
# Epoch 113/300
# -------------
# (train)
# -------------
# epoch 113 || Epoch_D_Loss:0.0816 ||Epoch_G_Loss:0.2053
# timer:  0.2930 sec.
# -------------
# Epoch 114/300
# -------------
# (train)
# -------------
# epoch 114 || Epoch_D_Loss:0.0718 ||Epoch_G_Loss:0.2333
# timer:  0.2945 sec.
# -------------
# Epoch 115/300
# -------------
# (train)
# -------------
# epoch 115 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.2306
# timer:  0.2967 sec.
# -------------
# Epoch 116/300
# -------------
# (train)
# -------------
# epoch 116 || Epoch_D_Loss:0.0782 ||Epoch_G_Loss:0.2141
# timer:  0.2877 sec.
# -------------
# Epoch 117/300
# -------------
# (train)
# -------------
# epoch 117 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.2564
# timer:  0.2999 sec.
# -------------
# Epoch 118/300
# -------------
# (train)
# -------------
# epoch 118 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.2343
# timer:  0.2939 sec.
# -------------
# Epoch 119/300
# -------------
# (train)
# -------------
# epoch 119 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.2369
# timer:  0.2967 sec.
# -------------
# Epoch 120/300
# -------------
# (train)
# -------------
# epoch 120 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.2245
# timer:  0.2917 sec.
# -------------
# Epoch 121/300
# -------------
# (train)
# -------------
# epoch 121 || Epoch_D_Loss:0.0676 ||Epoch_G_Loss:0.2299
# timer:  0.2956 sec.
# -------------
# Epoch 122/300
# -------------
# (train)
# -------------
# epoch 122 || Epoch_D_Loss:0.0727 ||Epoch_G_Loss:0.2508
# timer:  0.2929 sec.
# -------------
# Epoch 123/300
# -------------
# (train)
# -------------
# epoch 123 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.2276
# timer:  0.2953 sec.
# -------------
# Epoch 124/300
# -------------
# (train)
# -------------
# epoch 124 || Epoch_D_Loss:0.0780 ||Epoch_G_Loss:0.2527
# timer:  0.2886 sec.
# -------------
# Epoch 125/300
# -------------
# (train)
# -------------
# epoch 125 || Epoch_D_Loss:0.0695 ||Epoch_G_Loss:0.2439
# timer:  0.2913 sec.
# -------------
# Epoch 126/300
# -------------
# (train)
# -------------
# epoch 126 || Epoch_D_Loss:0.0680 ||Epoch_G_Loss:0.2457
# timer:  0.2930 sec.
# -------------
# Epoch 127/300
# -------------
# (train)
# -------------
# epoch 127 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.2503
# timer:  0.2941 sec.
# -------------
# Epoch 128/300
# -------------
# (train)
# -------------
# epoch 128 || Epoch_D_Loss:0.0572 ||Epoch_G_Loss:0.2810
# timer:  0.2899 sec.
# -------------
# Epoch 129/300
# -------------
# (train)
# -------------
# epoch 129 || Epoch_D_Loss:0.0688 ||Epoch_G_Loss:0.2597
# timer:  0.2958 sec.
# -------------
# Epoch 130/300
# -------------
# (train)
# -------------
# epoch 130 || Epoch_D_Loss:0.0654 ||Epoch_G_Loss:0.2543
# timer:  0.2910 sec.
# -------------
# Epoch 131/300
# -------------
# (train)
# -------------
# epoch 131 || Epoch_D_Loss:0.0629 ||Epoch_G_Loss:0.2706
# timer:  0.2933 sec.
# -------------
# Epoch 132/300
# -------------
# (train)
# -------------
# epoch 132 || Epoch_D_Loss:0.0776 ||Epoch_G_Loss:0.2578
# timer:  0.2939 sec.
# -------------
# Epoch 133/300
# -------------
# (train)
# -------------
# epoch 133 || Epoch_D_Loss:0.0683 ||Epoch_G_Loss:0.2406
# timer:  0.2896 sec.
# -------------
# Epoch 134/300
# -------------
# (train)
# -------------
# epoch 134 || Epoch_D_Loss:0.0679 ||Epoch_G_Loss:0.2849
# timer:  0.2921 sec.
# -------------
# Epoch 135/300
# -------------
# (train)
# -------------
# epoch 135 || Epoch_D_Loss:0.0546 ||Epoch_G_Loss:0.2411
# timer:  0.2929 sec.
# -------------
# Epoch 136/300
# -------------
# (train)
# -------------
# epoch 136 || Epoch_D_Loss:0.0863 ||Epoch_G_Loss:0.2645
# timer:  0.2882 sec.
# -------------
# Epoch 137/300
# -------------
# (train)
# -------------
# epoch 137 || Epoch_D_Loss:0.0548 ||Epoch_G_Loss:0.2564
# timer:  0.2914 sec.
# -------------
# Epoch 138/300
# -------------
# (train)
# -------------
# epoch 138 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.2906
# timer:  0.2949 sec.
# -------------
# Epoch 139/300
# -------------
# (train)
# -------------
# epoch 139 || Epoch_D_Loss:0.0551 ||Epoch_G_Loss:0.2636
# timer:  0.2899 sec.
# -------------
# Epoch 140/300
# -------------
# (train)
# -------------
# epoch 140 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.2626
# timer:  0.2917 sec.
# -------------
# Epoch 141/300
# -------------
# (train)
# -------------
# epoch 141 || Epoch_D_Loss:0.0560 ||Epoch_G_Loss:0.2853
# timer:  0.2937 sec.
# -------------
# Epoch 142/300
# -------------
# (train)
# -------------
# epoch 142 || Epoch_D_Loss:0.0790 ||Epoch_G_Loss:0.2645
# timer:  0.2864 sec.
# -------------
# Epoch 143/300
# -------------
# (train)
# -------------
# epoch 143 || Epoch_D_Loss:0.0485 ||Epoch_G_Loss:0.2905
# timer:  0.2898 sec.
# -------------
# Epoch 144/300
# -------------
# (train)
# -------------
# epoch 144 || Epoch_D_Loss:0.0624 ||Epoch_G_Loss:0.2716
# timer:  0.2932 sec.
# -------------
# Epoch 145/300
# -------------
# (train)
# -------------
# epoch 145 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2965
# timer:  0.2966 sec.
# -------------
# Epoch 146/300
# -------------
# (train)
# -------------
# epoch 146 || Epoch_D_Loss:0.0661 ||Epoch_G_Loss:0.2597
# timer:  0.2890 sec.
# -------------
# Epoch 147/300
# -------------
# (train)
# -------------
# epoch 147 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.2851
# timer:  0.2954 sec.
# -------------
# Epoch 148/300
# -------------
# (train)
# -------------
# epoch 148 || Epoch_D_Loss:0.0557 ||Epoch_G_Loss:0.2909
# timer:  0.2878 sec.
# -------------
# Epoch 149/300
# -------------
# (train)
# -------------
# epoch 149 || Epoch_D_Loss:0.0484 ||Epoch_G_Loss:0.2966
# timer:  0.2960 sec.
# -------------
# Epoch 150/300
# -------------
# (train)
# -------------
# epoch 150 || Epoch_D_Loss:0.0609 ||Epoch_G_Loss:0.2691
# timer:  0.2902 sec.
# -------------
# Epoch 151/300
# -------------
# (train)
# -------------
# epoch 151 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.2973
# timer:  0.2896 sec.
# -------------
# Epoch 152/300
# -------------
# (train)
# -------------
# epoch 152 || Epoch_D_Loss:0.0644 ||Epoch_G_Loss:0.2764
# timer:  0.2940 sec.
# -------------
# Epoch 153/300
# -------------
# (train)
# -------------
# epoch 153 || Epoch_D_Loss:0.0477 ||Epoch_G_Loss:0.3118
# timer:  0.2882 sec.
# -------------
# Epoch 154/300
# -------------
# (train)
# -------------
# epoch 154 || Epoch_D_Loss:0.0537 ||Epoch_G_Loss:0.2952
# timer:  0.2963 sec.
# -------------
# Epoch 155/300
# -------------
# (train)
# -------------
# epoch 155 || Epoch_D_Loss:0.0464 ||Epoch_G_Loss:0.3155
# timer:  0.2897 sec.
# -------------
# Epoch 156/300
# -------------
# (train)
# -------------
# epoch 156 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.3005
# timer:  0.2931 sec.
# -------------
# Epoch 157/300
# -------------
# (train)
# -------------
# epoch 157 || Epoch_D_Loss:0.0442 ||Epoch_G_Loss:0.3172
# timer:  0.2924 sec.
# -------------
# Epoch 158/300
# -------------
# (train)
# -------------
# epoch 158 || Epoch_D_Loss:0.0623 ||Epoch_G_Loss:0.2959
# timer:  0.2969 sec.
# -------------
# Epoch 159/300
# -------------
# (train)
# -------------
# epoch 159 || Epoch_D_Loss:0.0542 ||Epoch_G_Loss:0.3114
# timer:  0.2874 sec.
# -------------
# Epoch 160/300
# -------------
# (train)
# -------------
# epoch 160 || Epoch_D_Loss:0.0430 ||Epoch_G_Loss:0.3103
# timer:  0.2925 sec.
# -------------
# Epoch 161/300
# -------------
# (train)
# -------------
# epoch 161 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.3418
# timer:  0.2931 sec.
# -------------
# Epoch 162/300
# -------------
# (train)
# -------------
# epoch 162 || Epoch_D_Loss:0.0501 ||Epoch_G_Loss:0.3181
# timer:  0.2893 sec.
# -------------
# Epoch 163/300
# -------------
# (train)
# -------------
# epoch 163 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.3261
# timer:  0.2945 sec.
# -------------
# Epoch 164/300
# -------------
# (train)
# -------------
# epoch 164 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.3116
# timer:  0.2975 sec.
# -------------
# Epoch 165/300
# -------------
# (train)
# -------------
# epoch 165 || Epoch_D_Loss:0.0365 ||Epoch_G_Loss:0.3644
# timer:  0.2905 sec.
# -------------
# Epoch 166/300
# -------------
# (train)
# -------------
# epoch 166 || Epoch_D_Loss:0.0521 ||Epoch_G_Loss:0.3052
# timer:  0.2907 sec.
# -------------
# Epoch 167/300
# -------------
# (train)
# -------------
# epoch 167 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.3495
# timer:  0.2888 sec.
# -------------
# Epoch 168/300
# -------------
# (train)
# -------------
# epoch 168 || Epoch_D_Loss:0.0683 ||Epoch_G_Loss:0.3209
# timer:  0.2902 sec.
# -------------
# Epoch 169/300
# -------------
# (train)
# -------------
# epoch 169 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.3501
# timer:  0.2954 sec.
# -------------
# Epoch 170/300
# -------------
# (train)
# -------------
# epoch 170 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.3288
# timer:  0.2950 sec.
# -------------
# Epoch 171/300
# -------------
# (train)
# -------------
# epoch 171 || Epoch_D_Loss:0.0452 ||Epoch_G_Loss:0.3297
# timer:  0.2905 sec.
# -------------
# Epoch 172/300
# -------------
# (train)
# -------------
# epoch 172 || Epoch_D_Loss:0.0440 ||Epoch_G_Loss:0.3758
# timer:  0.2977 sec.
# -------------
# Epoch 173/300
# -------------
# (train)
# -------------
# epoch 173 || Epoch_D_Loss:0.0454 ||Epoch_G_Loss:0.3111
# timer:  0.2935 sec.
# -------------
# Epoch 174/300
# -------------
# (train)
# -------------
# epoch 174 || Epoch_D_Loss:0.0504 ||Epoch_G_Loss:0.3655
# timer:  0.3004 sec.
# -------------
# Epoch 175/300
# -------------
# (train)
# -------------
# epoch 175 || Epoch_D_Loss:0.0467 ||Epoch_G_Loss:0.3424
# timer:  0.2889 sec.
# -------------
# Epoch 176/300
# -------------
# (train)
# -------------
# epoch 176 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:0.3525
# timer:  0.2890 sec.
# -------------
# Epoch 177/300
# -------------
# (train)
# -------------
# epoch 177 || Epoch_D_Loss:0.0341 ||Epoch_G_Loss:0.3681
# timer:  0.2960 sec.
# -------------
# Epoch 178/300
# -------------
# (train)
# -------------
# epoch 178 || Epoch_D_Loss:0.0522 ||Epoch_G_Loss:0.3633
# timer:  0.2962 sec.
# -------------
# Epoch 179/300
# -------------
# (train)
# -------------
# epoch 179 || Epoch_D_Loss:0.0545 ||Epoch_G_Loss:0.3136
# timer:  0.2925 sec.
# -------------
# Epoch 180/300
# -------------
# (train)
# -------------
# epoch 180 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.3746
# timer:  0.2945 sec.
# -------------
# Epoch 181/300
# -------------
# (train)
# -------------
# epoch 181 || Epoch_D_Loss:0.0301 ||Epoch_G_Loss:0.3470
# timer:  0.2923 sec.
# -------------
# Epoch 182/300
# -------------
# (train)
# -------------
# epoch 182 || Epoch_D_Loss:0.0528 ||Epoch_G_Loss:0.3527
# timer:  0.2956 sec.
# -------------
# Epoch 183/300
# -------------
# (train)
# -------------
# epoch 183 || Epoch_D_Loss:0.0467 ||Epoch_G_Loss:0.3661
# timer:  0.2907 sec.
# -------------
# Epoch 184/300
# -------------
# (train)
# -------------
# epoch 184 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.3633
# timer:  0.2930 sec.
# -------------
# Epoch 185/300
# -------------
# (train)
# -------------
# epoch 185 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.3626
# timer:  0.2967 sec.
# -------------
# Epoch 186/300
# -------------
# (train)
# -------------
# epoch 186 || Epoch_D_Loss:0.0422 ||Epoch_G_Loss:0.3502
# timer:  0.2875 sec.
# -------------
# Epoch 187/300
# -------------
# (train)
# -------------
# epoch 187 || Epoch_D_Loss:0.0421 ||Epoch_G_Loss:0.3997
# timer:  0.2990 sec.
# -------------
# Epoch 188/300
# -------------
# (train)
# -------------
# epoch 188 || Epoch_D_Loss:0.0417 ||Epoch_G_Loss:0.3708
# timer:  0.2951 sec.
# -------------
# Epoch 189/300
# -------------
# (train)
# -------------
# epoch 189 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.4215
# timer:  0.2908 sec.
# -------------
# Epoch 190/300
# -------------
# (train)
# -------------
# epoch 190 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:0.3348
# timer:  0.2900 sec.
# -------------
# Epoch 191/300
# -------------
# (train)
# -------------
# epoch 191 || Epoch_D_Loss:0.0352 ||Epoch_G_Loss:0.4038
# timer:  0.2888 sec.
# -------------
# Epoch 192/300
# -------------
# (train)
# -------------
# epoch 192 || Epoch_D_Loss:0.0348 ||Epoch_G_Loss:0.4134
# timer:  0.2957 sec.
# -------------
# Epoch 193/300
# -------------
# (train)
# -------------
# epoch 193 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.4067
# timer:  0.2956 sec.
# -------------
# Epoch 194/300
# -------------
# (train)
# -------------
# epoch 194 || Epoch_D_Loss:0.0323 ||Epoch_G_Loss:0.4247
# timer:  0.2955 sec.
# -------------
# Epoch 195/300
# -------------
# (train)
# -------------
# epoch 195 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.3901
# timer:  0.2922 sec.
# -------------
# Epoch 196/300
# -------------
# (train)
# -------------
# epoch 196 || Epoch_D_Loss:0.0398 ||Epoch_G_Loss:0.3623
# timer:  0.2949 sec.
# -------------
# Epoch 197/300
# -------------
# (train)
# -------------
# epoch 197 || Epoch_D_Loss:0.0309 ||Epoch_G_Loss:0.4208
# timer:  0.2937 sec.
# -------------
# Epoch 198/300
# -------------
# (train)
# -------------
# epoch 198 || Epoch_D_Loss:0.0407 ||Epoch_G_Loss:0.4060
# timer:  0.2922 sec.
# -------------
# Epoch 199/300
# -------------
# (train)
# -------------
# epoch 199 || Epoch_D_Loss:0.0416 ||Epoch_G_Loss:0.4076
# timer:  0.2921 sec.
# -------------
# Epoch 200/300
# -------------
# (train)
# -------------
# epoch 200 || Epoch_D_Loss:0.0322 ||Epoch_G_Loss:0.4020
# timer:  0.2926 sec.
# -------------
# Epoch 201/300
# -------------
# (train)
# -------------
# epoch 201 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.4612
# timer:  0.2898 sec.
# -------------
# Epoch 202/300
# -------------
# (train)
# -------------
# epoch 202 || Epoch_D_Loss:0.0377 ||Epoch_G_Loss:0.4339
# timer:  0.2864 sec.
# -------------
# Epoch 203/300
# -------------
# (train)
# -------------
# epoch 203 || Epoch_D_Loss:0.0645 ||Epoch_G_Loss:0.3866
# timer:  0.2934 sec.
# -------------
# Epoch 204/300
# -------------
# (train)
# -------------
# epoch 204 || Epoch_D_Loss:0.0287 ||Epoch_G_Loss:0.3756
# timer:  0.2908 sec.
# -------------
# Epoch 205/300
# -------------
# (train)
# -------------
# epoch 205 || Epoch_D_Loss:0.0229 ||Epoch_G_Loss:0.4548
# timer:  0.2947 sec.
# -------------
# Epoch 206/300
# -------------
# (train)
# -------------
# epoch 206 || Epoch_D_Loss:0.0504 ||Epoch_G_Loss:0.4473
# timer:  0.2917 sec.
# -------------
# Epoch 207/300
# -------------
# (train)
# -------------
# epoch 207 || Epoch_D_Loss:0.0196 ||Epoch_G_Loss:0.4476
# timer:  0.2930 sec.
# -------------
# Epoch 208/300
# -------------
# (train)
# -------------
# epoch 208 || Epoch_D_Loss:0.0279 ||Epoch_G_Loss:0.4857
# timer:  0.2900 sec.
# -------------
# Epoch 209/300
# -------------
# (train)
# -------------
# epoch 209 || Epoch_D_Loss:0.0324 ||Epoch_G_Loss:0.4736
# timer:  0.2994 sec.
# -------------
# Epoch 210/300
# -------------
# (train)
# -------------
# epoch 210 || Epoch_D_Loss:0.0326 ||Epoch_G_Loss:0.4290
# timer:  0.2959 sec.
# -------------
# Epoch 211/300
# -------------
# (train)
# -------------
# epoch 211 || Epoch_D_Loss:0.0390 ||Epoch_G_Loss:0.4488
# timer:  0.2917 sec.
# -------------
# Epoch 212/300
# -------------
# (train)
# -------------
# epoch 212 || Epoch_D_Loss:0.0340 ||Epoch_G_Loss:0.4234
# timer:  0.2937 sec.
# -------------
# Epoch 213/300
# -------------
# (train)
# -------------
# epoch 213 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.4620
# timer:  0.2914 sec.
# -------------
# Epoch 214/300
# -------------
# (train)
# -------------
# epoch 214 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.4390
# timer:  0.2971 sec.
# -------------
# Epoch 215/300
# -------------
# (train)
# -------------
# epoch 215 || Epoch_D_Loss:0.0264 ||Epoch_G_Loss:0.4775
# timer:  0.2906 sec.
# -------------
# Epoch 216/300
# -------------
# (train)
# -------------
# epoch 216 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.4739
# timer:  0.2897 sec.
# -------------
# Epoch 217/300
# -------------
# (train)
# -------------
# epoch 217 || Epoch_D_Loss:0.0353 ||Epoch_G_Loss:0.4483
# timer:  0.2972 sec.
# -------------
# Epoch 218/300
# -------------
# (train)
# -------------
# epoch 218 || Epoch_D_Loss:0.0191 ||Epoch_G_Loss:0.4301
# timer:  0.2967 sec.
# -------------
# Epoch 219/300
# -------------
# (train)
# -------------
# epoch 219 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:0.4953
# timer:  0.2962 sec.
# -------------
# Epoch 220/300
# -------------
# (train)
# -------------
# epoch 220 || Epoch_D_Loss:0.0599 ||Epoch_G_Loss:0.4790
# timer:  0.2983 sec.
# -------------
# Epoch 221/300
# -------------
# (train)
# -------------
# epoch 221 || Epoch_D_Loss:0.0318 ||Epoch_G_Loss:0.3895
# timer:  0.3005 sec.
# -------------
# Epoch 222/300
# -------------
# (train)
# -------------
# epoch 222 || Epoch_D_Loss:0.0150 ||Epoch_G_Loss:0.4556
# timer:  0.2897 sec.
# -------------
# Epoch 223/300
# -------------
# (train)
# -------------
# epoch 223 || Epoch_D_Loss:0.0278 ||Epoch_G_Loss:0.4753
# timer:  0.2929 sec.
# -------------
# Epoch 224/300
# -------------
# (train)
# -------------
# epoch 224 || Epoch_D_Loss:0.0278 ||Epoch_G_Loss:0.4898
# timer:  0.2909 sec.
# -------------
# Epoch 225/300
# -------------
# (train)
# -------------
# epoch 225 || Epoch_D_Loss:0.0239 ||Epoch_G_Loss:0.5383
# timer:  0.2920 sec.
# -------------
# Epoch 226/300
# -------------
# (train)
# -------------
# epoch 226 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.3806
# timer:  0.2875 sec.
# -------------
# Epoch 227/300
# -------------
# (train)
# -------------
# epoch 227 || Epoch_D_Loss:0.0255 ||Epoch_G_Loss:0.4416
# timer:  0.2934 sec.
# -------------
# Epoch 228/300
# -------------
# (train)
# -------------
# epoch 228 || Epoch_D_Loss:0.0227 ||Epoch_G_Loss:0.4895
# timer:  0.2920 sec.
# -------------
# Epoch 229/300
# -------------
# (train)
# -------------
# epoch 229 || Epoch_D_Loss:0.0345 ||Epoch_G_Loss:0.4772
# timer:  0.2926 sec.
# -------------
# Epoch 230/300
# -------------
# (train)
# -------------
# epoch 230 || Epoch_D_Loss:0.0292 ||Epoch_G_Loss:0.4567
# timer:  0.2908 sec.
# -------------
# Epoch 231/300
# -------------
# (train)
# -------------
# epoch 231 || Epoch_D_Loss:0.0233 ||Epoch_G_Loss:0.5446
# timer:  0.3023 sec.
# -------------
# Epoch 232/300
# -------------
# (train)
# -------------
# epoch 232 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.4229
# timer:  0.2879 sec.
# -------------
# Epoch 233/300
# -------------
# (train)
# -------------
# epoch 233 || Epoch_D_Loss:0.0266 ||Epoch_G_Loss:0.5255
# timer:  0.2983 sec.
# -------------
# Epoch 234/300
# -------------
# (train)
# -------------
# epoch 234 || Epoch_D_Loss:0.0237 ||Epoch_G_Loss:0.5012
# timer:  0.2901 sec.
# -------------
# Epoch 235/300
# -------------
# (train)
# -------------
# epoch 235 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:0.5725
# timer:  0.2916 sec.
# -------------
# Epoch 236/300
# -------------
# (train)
# -------------
# epoch 236 || Epoch_D_Loss:0.0497 ||Epoch_G_Loss:0.4660
# timer:  0.2954 sec.
# -------------
# Epoch 237/300
# -------------
# (train)
# -------------
# epoch 237 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:0.5128
# timer:  0.2956 sec.
# -------------
# Epoch 238/300
# -------------
# (train)
# -------------
# epoch 238 || Epoch_D_Loss:0.0131 ||Epoch_G_Loss:0.5245
# timer:  0.2987 sec.
# -------------
# Epoch 239/300
# -------------
# (train)
# -------------
# epoch 239 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.5470
# timer:  0.2941 sec.
# -------------
# Epoch 240/300
# -------------
# (train)
# -------------
# epoch 240 || Epoch_D_Loss:0.0240 ||Epoch_G_Loss:0.5737
# timer:  0.2899 sec.
# -------------
# Epoch 241/300
# -------------
# (train)
# -------------
# epoch 241 || Epoch_D_Loss:0.0347 ||Epoch_G_Loss:0.4823
# timer:  0.2965 sec.
# -------------
# Epoch 242/300
# -------------
# (train)
# -------------
# epoch 242 || Epoch_D_Loss:0.0289 ||Epoch_G_Loss:0.5404
# timer:  0.2879 sec.
# -------------
# Epoch 243/300
# -------------
# (train)
# -------------
# epoch 243 || Epoch_D_Loss:0.0143 ||Epoch_G_Loss:0.4799
# timer:  0.2999 sec.
# -------------
# Epoch 244/300
# -------------
# (train)
# -------------
# epoch 244 || Epoch_D_Loss:0.0381 ||Epoch_G_Loss:0.5088
# timer:  0.2944 sec.
# -------------
# Epoch 245/300
# -------------
# (train)
# -------------
# epoch 245 || Epoch_D_Loss:0.0241 ||Epoch_G_Loss:0.5080
# timer:  0.2941 sec.
# -------------
# Epoch 246/300
# -------------
# (train)
# -------------
# epoch 246 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.5148
# timer:  0.2898 sec.
# -------------
# Epoch 247/300
# -------------
# (train)
# -------------
# epoch 247 || Epoch_D_Loss:0.0381 ||Epoch_G_Loss:0.5245
# timer:  0.2966 sec.
# -------------
# Epoch 248/300
# -------------
# (train)
# -------------
# epoch 248 || Epoch_D_Loss:0.0120 ||Epoch_G_Loss:0.5016
# timer:  0.2878 sec.
# -------------
# Epoch 249/300
# -------------
# (train)
# -------------
# epoch 249 || Epoch_D_Loss:0.0149 ||Epoch_G_Loss:0.6380
# timer:  0.2988 sec.
# -------------
# Epoch 250/300
# -------------
# (train)
# -------------
# epoch 250 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.5414
# timer:  0.2938 sec.
# -------------
# Epoch 251/300
# -------------
# (train)
# -------------
# epoch 251 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.5371
# timer:  0.2962 sec.
# -------------
# Epoch 252/300
# -------------
# (train)
# -------------
# epoch 252 || Epoch_D_Loss:0.0186 ||Epoch_G_Loss:0.5693
# timer:  0.2901 sec.
# -------------
# Epoch 253/300
# -------------
# (train)
# -------------
# epoch 253 || Epoch_D_Loss:0.0353 ||Epoch_G_Loss:0.5178
# timer:  0.2953 sec.
# -------------
# Epoch 254/300
# -------------
# (train)
# -------------
# epoch 254 || Epoch_D_Loss:0.0246 ||Epoch_G_Loss:0.5463
# timer:  0.2930 sec.
# -------------
# Epoch 255/300
# -------------
# (train)
# -------------
# epoch 255 || Epoch_D_Loss:0.0206 ||Epoch_G_Loss:0.5124
# timer:  0.2986 sec.
# -------------
# Epoch 256/300
# -------------
# (train)
# -------------
# epoch 256 || Epoch_D_Loss:0.0079 ||Epoch_G_Loss:0.5886
# timer:  0.2935 sec.
# -------------
# Epoch 257/300
# -------------
# (train)
# -------------
# epoch 257 || Epoch_D_Loss:0.0361 ||Epoch_G_Loss:0.6183
# timer:  0.2896 sec.
# -------------
# Epoch 258/300
# -------------
# (train)
# -------------
# epoch 258 || Epoch_D_Loss:0.0296 ||Epoch_G_Loss:0.4533
# timer:  0.2943 sec.
# -------------
# Epoch 259/300
# -------------
# (train)
# -------------
# epoch 259 || Epoch_D_Loss:0.0119 ||Epoch_G_Loss:0.5300
# timer:  0.2882 sec.
# -------------
# Epoch 260/300
# -------------
# (train)
# -------------
# epoch 260 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.5677
# timer:  0.2890 sec.
# -------------
# Epoch 261/300
# -------------
# (train)
# -------------
# epoch 261 || Epoch_D_Loss:0.0365 ||Epoch_G_Loss:0.4599
# timer:  0.2909 sec.
# -------------
# Epoch 262/300
# -------------
# (train)
# -------------
# epoch 262 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.5481
# timer:  0.2934 sec.
# -------------
# Epoch 263/300
# -------------
# (train)
# -------------
# epoch 263 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:0.5413
# timer:  0.2901 sec.
# -------------
# Epoch 264/300
# -------------
# (train)
# -------------
# epoch 264 || Epoch_D_Loss:0.0087 ||Epoch_G_Loss:0.5815
# timer:  0.2904 sec.
# -------------
# Epoch 265/300
# -------------
# (train)
# -------------
# epoch 265 || Epoch_D_Loss:0.0319 ||Epoch_G_Loss:0.5982
# timer:  0.2930 sec.
# -------------
# Epoch 266/300
# -------------
# (train)
# -------------
# epoch 266 || Epoch_D_Loss:0.0168 ||Epoch_G_Loss:0.6091
# timer:  0.2885 sec.
# -------------
# Epoch 267/300
# -------------
# (train)
# -------------
# epoch 267 || Epoch_D_Loss:0.0276 ||Epoch_G_Loss:0.4980
# timer:  0.2924 sec.
# -------------
# Epoch 268/300
# -------------
# (train)
# -------------
# epoch 268 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.5679
# timer:  0.2891 sec.
# -------------
# Epoch 269/300
# -------------
# (train)
# -------------
# epoch 269 || Epoch_D_Loss:0.0212 ||Epoch_G_Loss:0.6243
# timer:  0.2930 sec.
# -------------
# Epoch 270/300
# -------------
# (train)
# -------------
# epoch 270 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.5808
# timer:  0.2891 sec.
# -------------
# Epoch 271/300
# -------------
# (train)
# -------------
# epoch 271 || Epoch_D_Loss:0.0213 ||Epoch_G_Loss:0.6009
# timer:  0.2925 sec.
# -------------
# Epoch 272/300
# -------------
# (train)
# -------------
# epoch 272 || Epoch_D_Loss:0.0204 ||Epoch_G_Loss:0.5702
# timer:  0.2912 sec.
# -------------
# Epoch 273/300
# -------------
# (train)
# -------------
# epoch 273 || Epoch_D_Loss:0.0165 ||Epoch_G_Loss:0.6054
# timer:  0.2911 sec.
# -------------
# Epoch 274/300
# -------------
# (train)
# -------------
# epoch 274 || Epoch_D_Loss:0.0150 ||Epoch_G_Loss:0.5791
# timer:  0.2928 sec.
# -------------
# Epoch 275/300
# -------------
# (train)
# -------------
# epoch 275 || Epoch_D_Loss:0.0094 ||Epoch_G_Loss:0.6067
# timer:  0.2906 sec.
# -------------
# Epoch 276/300
# -------------
# (train)
# -------------
# epoch 276 || Epoch_D_Loss:0.0464 ||Epoch_G_Loss:0.4986
# timer:  0.2964 sec.
# -------------
# Epoch 277/300
# -------------
# (train)
# -------------
# epoch 277 || Epoch_D_Loss:0.0296 ||Epoch_G_Loss:0.5587
# timer:  0.2908 sec.
# -------------
# Epoch 278/300
# -------------
# (train)
# -------------
# epoch 278 || Epoch_D_Loss:0.0227 ||Epoch_G_Loss:0.5611
# timer:  0.2962 sec.
# -------------
# Epoch 279/300
# -------------
# (train)
# -------------
# epoch 279 || Epoch_D_Loss:0.0145 ||Epoch_G_Loss:0.5142
# timer:  0.2872 sec.
# -------------
# Epoch 280/300
# -------------
# (train)
# -------------
# epoch 280 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.6043
# timer:  0.2945 sec.
# -------------
# Epoch 281/300
# -------------
# (train)
# -------------
# epoch 281 || Epoch_D_Loss:0.0254 ||Epoch_G_Loss:0.6540
# timer:  0.2906 sec.
# -------------
# Epoch 282/300
# -------------
# (train)
# -------------
# epoch 282 || Epoch_D_Loss:0.0117 ||Epoch_G_Loss:0.5494
# timer:  0.2865 sec.
# -------------
# Epoch 283/300
# -------------
# (train)
# -------------
# epoch 283 || Epoch_D_Loss:0.0189 ||Epoch_G_Loss:0.6584
# timer:  0.2933 sec.
# -------------
# Epoch 284/300
# -------------
# (train)
# -------------
# epoch 284 || Epoch_D_Loss:0.0174 ||Epoch_G_Loss:0.5763
# timer:  0.2929 sec.
# -------------
# Epoch 285/300
# -------------
# (train)
# -------------
# epoch 285 || Epoch_D_Loss:0.0273 ||Epoch_G_Loss:0.6041
# timer:  0.2896 sec.
# -------------
# Epoch 286/300
# -------------
# (train)
# -------------
# epoch 286 || Epoch_D_Loss:0.0054 ||Epoch_G_Loss:0.5875
# timer:  0.2942 sec.
# -------------
# Epoch 287/300
# -------------
# (train)
# -------------
# epoch 287 || Epoch_D_Loss:0.0332 ||Epoch_G_Loss:0.6145
# timer:  0.2965 sec.
# -------------
# Epoch 288/300
# -------------
# (train)
# -------------
# epoch 288 || Epoch_D_Loss:0.0222 ||Epoch_G_Loss:0.5838
# timer:  0.2945 sec.
# -------------
# Epoch 289/300
# -------------
# (train)
# -------------
# epoch 289 || Epoch_D_Loss:0.0092 ||Epoch_G_Loss:0.5359
# timer:  0.2995 sec.
# -------------
# Epoch 290/300
# -------------
# (train)
# -------------
# epoch 290 || Epoch_D_Loss:0.0043 ||Epoch_G_Loss:0.6491
# timer:  0.2973 sec.
# -------------
# Epoch 291/300
# -------------
# (train)
# -------------
# epoch 291 || Epoch_D_Loss:0.0150 ||Epoch_G_Loss:0.5803
# timer:  0.2924 sec.
# -------------
# Epoch 292/300
# -------------
# (train)
# -------------
# epoch 292 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.6459
# timer:  0.2903 sec.
# -------------
# Epoch 293/300
# -------------
# (train)
# -------------
# epoch 293 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.6714
# timer:  0.2918 sec.
# -------------
# Epoch 294/300
# -------------
# (train)
# -------------
# epoch 294 || Epoch_D_Loss:0.0183 ||Epoch_G_Loss:0.6886
# timer:  0.2920 sec.
# -------------
# Epoch 295/300
# -------------
# (train)
# -------------
# epoch 295 || Epoch_D_Loss:0.0059 ||Epoch_G_Loss:0.6366
# timer:  0.2961 sec.
# -------------
# Epoch 296/300
# -------------
# (train)
# -------------
# epoch 296 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.6524
# timer:  0.2966 sec.
# -------------
# Epoch 297/300
# -------------
# (train)
# -------------
# epoch 297 || Epoch_D_Loss:0.0396 ||Epoch_G_Loss:0.7206
# timer:  0.2911 sec.
# -------------
# Epoch 298/300
# -------------
# (train)
# -------------
# epoch 298 || Epoch_D_Loss:0.0070 ||Epoch_G_Loss:0.6083
# timer:  0.2924 sec.
# -------------
# Epoch 299/300
# -------------
# (train)
# -------------
# epoch 299 || Epoch_D_Loss:0.0109 ||Epoch_G_Loss:0.6569
# timer:  0.2874 sec.
# 총 반복 횟수:  2101

# %%
# 생성 이미지와 훈련 데이터를 시각화한다
# 이 셀은 몇 번을 재실행하고 있습니다.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 입력 난수 생성
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)
fake_images = G_update(fixed_z.to(device))

# 훈련 데이터
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다


# 출력
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 상단에 훈련 데이터를,
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 하단에 생성 데이터를 표시한다
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# ## 테스트 화상으로 이상 탐지

# %%
# 테스트용 DataLoader 작성
def make_test_datapath_list():
    """학습 및 검증 화상 데이터와 어노테이션 데이터의 파일 경로 리스트를 작성한다. """

    train_img_list = list()  # 화상 파일 경로를 저장

    for img_idx in range(5):
        img_path = "./data/test/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# 파일 리스트를 작성
test_img_list = make_test_datapath_list()

# Dataset 작성
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoader 작성
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# 테스트 데이터 확인
import matplotlib.pyplot as plt

batch_iterator = iter(test_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  

# 첫번째 미니 배치를 꺼낸다
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
# 이상 탐지할 이미지
x = imges[0:5]
x = x.to(device)

z = torch.randn(5, 20).to(device)
z = z.view(z.size(0), z.size(1), 1, 1)

z.requires_grad = True

z_optimizer = torch.optim.Adam([z], lr=1e-3)

for epoch in range(6000+1):
    fake_img = G_update(z)
    loss, _, _ = Anomaly_score(x,fake_img, D_update, Lambda=0.1)

    z_optimizer.zero_grad()
    loss.backward()
    z_optimizer.step()

    
    if epoch % 1000 == 0:
        print('epoch {} || loss_total:{:.0f} '.format(epoch, loss.item()))
# Out:
# epoch 0 || loss_total:5078
# epoch 1000 || loss_total:2542
# epoch 2000 || loss_total:1751
# epoch 3000 || loss_total:1473
# epoch 4000 || loss_total:1351
# epoch 5000 || loss_total:1303
# epoch 6000 || loss_total:1271

# %%
G_update.eval()
fake_img = G_update(z)

loss, loss_each, residual_loss_each = Anomaly_score(x, fake_img, D_update, Lambda=0.1)

loss_each = loss_each.cpu().detach().numpy()
print("total loss: ", np.round(loss_each, 0))

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_img[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss:  [239. 236. 457. 195. 144.]
